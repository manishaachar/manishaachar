# %%
#line Plot
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,4,6,8])
y=x*2
plt.plot(x,y)
plt.show()

# %%
#Box plot
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.rand(20,5),
columns=['A','B','C','D','E'])
df.plot.box(grid="True")
# Out:
# <AxesSubplot:>

# %%
#Scatter Plot
from matplotlib import pyplot as plt
x=[74,88,52,72,78]
y=[23,22,54,69,80]
plt.scatter(x,y)
plt.legend("Hello")
plt.show()

# %%
from matplotlib import pyplot as plt
y=[1,15,19,40,65]
plt.hist(y)
# Out:
# (array([1., 0., 2., 0., 0., 0., 1., 0., 0., 1.]),
#  array([ 1. ,  7.4, 13.8, 20.2, 26.6, 33. , 39.4, 45.8, 52.2, 58.6, 65. ]),
#  <BarContainer object of 10 artists>)

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
data=[{8,9,3,4},{4,6,9,1},{7,4,1,3},{9,5,1,3},{7,1,3,9}]
Index=['I1','I2','I3','I4','I5']
Cols=['C1','C2','C3','C4']
df=DataFrame(data,index=Index,columns=Cols)
plt.pcolor(df)
plt.show()

# %%
from matplotlib import pyplot as plt
y=[1,15,19,40,65]
plt.hist(y)
plt.show()

# %%
from matplotlib import pyplot
import random
data=[[random.randint(0,256)for x in range(0,5)],#r1
     [random.randint(0,256)for x in range(0,5)], #r2
     [random.randint(0,256)for x in range(0,5)], #r3
     [random.randint(0,256)for x in range(0,5)], #r4
     [random.randint(0,256)for x in range(0,5)], #r5
     [random.randint(0,256)for x in range(0,5)]] #r6
data
# Out:
# [[163, 29, 174, 28, 153],
#  [221, 170, 134, 43, 99],
#  [253, 217, 9, 255, 119],
#  [202, 236, 17, 48, 224],
#  [91, 112, 216, 0, 254],
#  [158, 203, 55, 115, 3]]

# %%
from matplotlib import color
pyplot figure(figsize=(5,5))
# Out:
#   File "/tmp/ipykernel_2820/2256741317.py", line 2
#     pyplot figure(figsize=(5,5))
#            ^
# SyntaxError: invalid syntax

# %%
#line graph
